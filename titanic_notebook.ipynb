# %%
# Competition: Titanic Data

# %%
import numpy as np
import pandas as pd
import os
# import sklearn
import tensorflow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 5
#       3 import os
#       4 # import sklearn
# ----> 5 import tensorflow
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
file_path = '/Users/needatea/Documents/Code Learning/Code Competitions/Kaggle_Titanic/titanic_data'
file_list = os.listdir(file_path)

print(file_list)

# for file in file_list:
#     globals()
#     pd.read_csv()
